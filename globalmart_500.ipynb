# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
import requests
response = requests.get('https://zucwflxqsxrsmwseehqvjmnx2u0cdigp.lambda-url.ap-south-1.on.aws/mentorskool/v1/sales?offset=1&limit=100', headers= {"access_token":"fe66583bfe5185048c66571293e0d358"})

# %%
response
# Out:
# <Response [200]>

# %%
print("Content:", response.text)
# Out:
# Content: {"data":[{"id":2698,"sales_amt":261.96,"qty":2,"discount":0.0,"profit_amt":41.9136,"order":{"order_id":"CA-2014-145317","ship_mode":"Standard Class","order_status":"delivered","order_purchase_date":"2018-07-11 19:46:00","order_approved_at":"2018-07-13 15:25","order_delivered_carrier_date":"2018-07-23 15:07","order_delivered_customer_date":"2018-07-24 14:58","order_estimated_delivery_date":"2018-07-27","customer":{"customer_id":"SM-20320","customer_name":"Sean Miller","segment":"Home Office","contact_number":"02342815792","address":{"zip_code":77070,"region":"Central","country":"United States","city":"houston","state":"texas"}},"vendor":{"VendorID":"VEN03","Vendor Name":"Voyage Enterprises"}},"product":{"product_id":"FUR-BO-10001798","product_name":"Bush Somerset Collection Bookcase","colors":"Pink","category":"Furniture","sub_category":"Bookcases","date_added":"2016-04-01","manufacturer":"null","sizes":"9","upc":640000000000,"weight":"null","product_photos_qty":4}},{"id":6827,"sales_amt":731.94,"qty":3,"discount":0.0,"profit_amt":219.582,"order":{"order_id":"CA-2016-118689","ship_mode":"Standard Class","order_status":"delivered","order_purchase_date":"2018-05-15 20:24:00","order_approved_at":"2018-05-15 20:55","order_delivered_carrier_date":"2018-05-29 14:59","order_delivered_customer_date":"2018-06-04 14:42","order_estimated_delivery_date":"2018-06-18","customer":{"customer_id":"TC-20980","customer_name":"Tamara Chand","segment":"Corporate","contact_number":"+1 582-201-9277","address":{"zip_code":45011,"region":"East","country":"United States","city":"hamilton","state":"ohio"}},"vendor":{"VendorID":"VEN01","Vendor Name":"Velocity Logistics"}},"product":{"product_id":"FUR-CH-10000454","product_name":"Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back","colors":"Pink","category":"Furniture","sub_category":"Chairs","date_added":"2016-11-04","manufacturer":"null","sizes":"10,7,6,9,8","upc":664000000000,"weight":"null","product_photos_qty":2}},{"id":8154,"sales_amt":14.62,"qty":2,"discount":0.0,"profit_amt":6.8714,"order":{"order_id":"CA-2017-140151","ship_mode":"First Class","order_status":"delivered","order_purchase_date":"2018-02-28 13:40:00","order_approved_at":"2018-03-01 13:35","order_delivered_carrier_date":"2018-03-02 00:55","order_delivered_customer_date":"2018-04-03 23:31","order_estimated_delivery_date":"2018-03-28","customer":{"customer_id":"RB-19360","customer_name":"Raymond Buch","segment":"Consumer","contact_number":"+1 385-724-6492","address":{"zip_code":99207,"region":"West","country":"United States","city":"spokane","state":"washington"}},"vendor":{"VendorID":"VEN02","Vendor Name":"Seaborne Ltd."}},"product":{"product_id":"OFF-LA-10000240","product_name":"Self-Adhesive Address Labels for Typewriters by Universal","colors":"Pink","category":"Office Supplies","sub_category":"Labels","date_added":"2016-08-01","manufacturer":"null","sizes":"11.5","upc":887000000000,"weight":"null","product_photos_qty":3}},{"id":2624,"sales_amt":957.5775,"qty":5,"discount":0.45,"profit_amt":-383.031,"order":{"order_id":"CA-2017-127180","ship_mode":"First Class","order_status":"delivered","order_purchase_date":"2018-01-07 21:45:00","order_approved_at":"2018-01-07 21:57","order_delivered_carrier_date":"2018-01-09 22:44","order_delivered_customer_date":"2018-01-30 20:51","order_estimated_delivery_date":"2018-02-07","customer":{"customer_id":"TA-21385","customer_name":"Tom Ashbrook","segment":"Home Office","contact_number":"0380281161","address":{"zip_code":10024,"region":"East","country":"United States","city":"new york city","state":"new york"}},"vendor":{"VendorID":"VEN01","Vendor Name":"Velocity Logistics"}},"product":{"product_id":"FUR-TA-10000577","product_name":"Bretford CR4500 Series Slim Rectangular Table","colors":"Blue","category":"Furniture","sub_category":"Tables","date_added":"2016-11-15","manufacturer":"null","sizes":"10.5,10,8.5,8,13","upc":888000000000,"weight":"null","product_photos_qty":0}},{"id":4191, ...

# %%
print("Status code:", response.status_code)
print(response.raise_for_status())
# Out:
# Status code: 200
# None

# %%
data=response.json()

# %%
import pandas as pd
import json
df1 = pd.DataFrame(data)
df1
# Out:
#                                                  data  count  limit  \
# 0   {'id': 2698, 'sales_amt': 261.96, 'qty': 2, 'd...   9819    100
# 1   {'id': 6827, 'sales_amt': 731.94, 'qty': 3, 'd...   9819    100
# 2   {'id': 8154, 'sales_amt': 14.62, 'qty': 2, 'di...   9819    100
# 3   {'id': 2624, 'sales_amt': 957.5775, 'qty': 5, ...   9819    100
# 4   {'id': 4191, 'sales_amt': 22.368, 'qty': 2, 'd...   9819    100
# ..                                                ...    ...    ...
# 95  {'id': 6011, 'sales_amt': 5.682, 'qty': 1, 'di...   9819    100
# 96  {'id': 7281, 'sales_amt': 96.53, 'qty': 7, 'di...   9819    100
# 97  {'id': 264, 'sales_amt': 51.312, 'qty': 3, 'di...   9819    100
# 98  {'id': 7938, 'sales_amt': 77.88, 'qty': 6, 'di...   9819    100
# 99  {'id': 3444, 'sales_amt': 64.624, 'qty': 7, 'd...   9819    100
#
#                                           next previous
# 0   /mentorskool/v1/sales?offset=101&limit=100
# 1   /mentorskool/v1/sales?offset=101&limit=100
# 2   /mentorskool/v1/sales?offset=101&limit=100
# 3   /mentorskool/v1/sales?offset=101&limit=100
# 4   /mentorskool/v1/sales?offset=101&limit=100
# ..                                         ...      ...
# 95  /mentorskool/v1/sales?offset=101&limit=100
# 96  /mentorskool/v1/sales?offset=101&limit=100
# 97  /mentorskool/v1/sales?offset=101&limit=100
# 98  /mentorskool/v1/sales?offset=101&limit=100
# 99  /mentorskool/v1/sales?offset=101&limit=100
#
# [100 rows x 5 columns]

# %%
import requests
response = requests.get('https://zucwflxqsxrsmwseehqvjmnx2u0cdigp.lambda-url.ap-south-1.on.aws/mentorskool/v1/sales?offset=101&limit=200', headers= {"access_token":"fe66583bfe5185048c66571293e0d358"})

data=response.json()

df2 = pd.DataFrame(data)
df2
# Out:
#                                                  data  count  limit  \
# 0   {'id': 5531, 'sales_amt': 95.976, 'qty': 3, 'd...   9819    100
# 1   {'id': 1439, 'sales_amt': 1.788, 'qty': 3, 'di...   9819    100
# 2   {'id': 3581, 'sales_amt': 23.92, 'qty': 4, 'di...   9819    100
# 3   {'id': 9949, 'sales_amt': 238.896, 'qty': 6, '...   9819    100
# 4   {'id': 4866, 'sales_amt': 102.36, 'qty': 3, 'd...   9819    100
# ..                                                ...    ...    ...
# 95  {'id': 722, 'sales_amt': 7.408, 'qty': 2, 'dis...   9819    100
# 96  {'id': 6877, 'sales_amt': 6.048, 'qty': 3, 'di...   9819    100
# 97  {'id': 5426, 'sales_amt': 46.26, 'qty': 3, 'di...   9819    100
# 98  {'id': 8302, 'sales_amt': 2.946, 'qty': 2, 'di...   9819    100
# 99  {'id': 9514, 'sales_amt': 16.056, 'qty': 3, 'd...   9819    100
#
#                                           next  \
# 0   /mentorskool/v1/sales?offset=201&limit=100
# 1   /mentorskool/v1/sales?offset=201&limit=100
# 2   /mentorskool/v1/sales?offset=201&limit=100
# 3   /mentorskool/v1/sales?offset=201&limit=100
# 4   /mentorskool/v1/sales?offset=201&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=201&limit=100
# 96  /mentorskool/v1/sales?offset=201&limit=100
# 97  /mentorskool/v1/sales?offset=201&limit=100
# 98  /mentorskool/v1/sales?offset=201&limit=100
# 99  /mentorskool/v1/sales?offset=201&limit=100
#
#                                     previous
# 0   /mentorskool/v1/sales?offset=1&limit=100
# 1   /mentorskool/v1/sales?offset=1&limit=100
# 2   /mentorskool/v1/sales?offset=1&limit=100
# 3   /mentorskool/v1/sales?offset=1&limit=100
# 4   /mentorskool/v1/sales?offset=1&limit=100
# ..                                       ...
# 95  /mentorskool/v1/sales?offset=1&limit=100
# 96  /mentorskool/v1/sales?offset=1&limit=100
# 97  /mentorskool/v1/sales?offset=1&limit=100
# 98  /mentorskool/v1/sales?offset=1&limit=100
# 99  /mentorskool/v1/sales?offset=1&limit=100
#
# [100 rows x 5 columns]

# %%
import requests
response = requests.get('https://zucwflxqsxrsmwseehqvjmnx2u0cdigp.lambda-url.ap-south-1.on.aws/mentorskool/v1/sales?offset=201&limit=300', headers= {"access_token":"fe66583bfe5185048c66571293e0d358"})

data=response.json()

df3 = pd.DataFrame(data)
df3
# Out:
#                                                  data  count  limit  \
# 0   {'id': 5435, 'sales_amt': 21.744, 'qty': 3, 'd...   9819    100
# 1   {'id': 6839, 'sales_amt': 218.75, 'qty': 2, 'd...   9819    100
# 2   {'id': 2929, 'sales_amt': 2.6, 'qty': 1, 'disc...   9819    100
# 3   {'id': 3184, 'sales_amt': 66.284, 'qty': 2, 'd...   9819    100
# 4   {'id': 2861, 'sales_amt': 35.168, 'qty': 7, 'd...   9819    100
# ..                                                ...    ...    ...
# 95  {'id': 558, 'sales_amt': 218.352, 'qty': 3, 'd...   9819    100
# 96  {'id': 4459, 'sales_amt': 78.6, 'qty': 5, 'dis...   9819    100
# 97  {'id': 2674, 'sales_amt': 27.552, 'qty': 3, 'd...   9819    100
# 98  {'id': 4938, 'sales_amt': 32.4, 'qty': 5, 'dis...   9819    100
# 99  {'id': 5560, 'sales_amt': 1082.48, 'qty': 8, '...   9819    100
#
#                                           next  \
# 0   /mentorskool/v1/sales?offset=301&limit=100
# 1   /mentorskool/v1/sales?offset=301&limit=100
# 2   /mentorskool/v1/sales?offset=301&limit=100
# 3   /mentorskool/v1/sales?offset=301&limit=100
# 4   /mentorskool/v1/sales?offset=301&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=301&limit=100
# 96  /mentorskool/v1/sales?offset=301&limit=100
# 97  /mentorskool/v1/sales?offset=301&limit=100
# 98  /mentorskool/v1/sales?offset=301&limit=100
# 99  /mentorskool/v1/sales?offset=301&limit=100
#
#                                       previous
# 0   /mentorskool/v1/sales?offset=101&limit=100
# 1   /mentorskool/v1/sales?offset=101&limit=100
# 2   /mentorskool/v1/sales?offset=101&limit=100
# 3   /mentorskool/v1/sales?offset=101&limit=100
# 4   /mentorskool/v1/sales?offset=101&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=101&limit=100
# 96  /mentorskool/v1/sales?offset=101&limit=100
# 97  /mentorskool/v1/sales?offset=101&limit=100
# 98  /mentorskool/v1/sales?offset=101&limit=100
# 99  /mentorskool/v1/sales?offset=101&limit=100
#
# [100 rows x 5 columns]

# %%
import requests
response = requests.get('https://zucwflxqsxrsmwseehqvjmnx2u0cdigp.lambda-url.ap-south-1.on.aws/mentorskool/v1/sales?offset=301&limit=400', headers= {"access_token":"fe66583bfe5185048c66571293e0d358"})

data=response.json()

df4 = pd.DataFrame(data)
df4
# Out:
#                                                  data  count  limit  \
# 0   {'id': 4988, 'sales_amt': 56.91, 'qty': 3, 'di...   9819    100
# 1   {'id': 5639, 'sales_amt': 77.6, 'qty': 4, 'dis...   9819    100
# 2   {'id': 8010, 'sales_amt': 14.28, 'qty': 1, 'di...   9819    100
# 3   {'id': 1181, 'sales_amt': 219.075, 'qty': 3, '...   9819    100
# 4   {'id': 2478, 'sales_amt': 26.8, 'qty': 2, 'dis...   9819    100
# ..                                                ...    ...    ...
# 95  {'id': 68, 'sales_amt': 49.96, 'qty': 2, 'disc...   9819    100
# 96  {'id': 9173, 'sales_amt': 12.96, 'qty': 2, 'di...   9819    100
# 97  {'id': 1082, 'sales_amt': 70.12, 'qty': 4, 'di...   9819    100
# 98  {'id': 4284, 'sales_amt': 35.952, 'qty': 3, 'd...   9819    100
# 99  {'id': 2477, 'sales_amt': 2396.2656, 'qty': 4,...   9819    100
#
#                                           next  \
# 0   /mentorskool/v1/sales?offset=401&limit=100
# 1   /mentorskool/v1/sales?offset=401&limit=100
# 2   /mentorskool/v1/sales?offset=401&limit=100
# 3   /mentorskool/v1/sales?offset=401&limit=100
# 4   /mentorskool/v1/sales?offset=401&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=401&limit=100
# 96  /mentorskool/v1/sales?offset=401&limit=100
# 97  /mentorskool/v1/sales?offset=401&limit=100
# 98  /mentorskool/v1/sales?offset=401&limit=100
# 99  /mentorskool/v1/sales?offset=401&limit=100
#
#                                       previous
# 0   /mentorskool/v1/sales?offset=201&limit=100
# 1   /mentorskool/v1/sales?offset=201&limit=100
# 2   /mentorskool/v1/sales?offset=201&limit=100
# 3   /mentorskool/v1/sales?offset=201&limit=100
# 4   /mentorskool/v1/sales?offset=201&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=201&limit=100
# 96  /mentorskool/v1/sales?offset=201&limit=100
# 97  /mentorskool/v1/sales?offset=201&limit=100
# 98  /mentorskool/v1/sales?offset=201&limit=100
# 99  /mentorskool/v1/sales?offset=201&limit=100
#
# [100 rows x 5 columns]

# %%
import requests
response = requests.get('https://zucwflxqsxrsmwseehqvjmnx2u0cdigp.lambda-url.ap-south-1.on.aws/mentorskool/v1/sales?offset=401&limit=500', headers= {"access_token":"fe66583bfe5185048c66571293e0d358"})

data=response.json()

df5 = pd.DataFrame(data)
df5
# Out:
#                                                  data  count  limit  \
# 0   {'id': 1253, 'sales_amt': 131.136, 'qty': 4, '...   9819    100
# 1   {'id': 9430, 'sales_amt': 57.584, 'qty': 2, 'd...   9819    100
# 2   {'id': 5926, 'sales_amt': 9.568, 'qty': 2, 'di...   9819    100
# 3   {'id': 36, 'sales_amt': 39.072, 'qty': 6, 'dis...   9819    100
# 4   {'id': 9505, 'sales_amt': 35.91, 'qty': 3, 'di...   9819    100
# ..                                                ...    ...    ...
# 95  {'id': 336, 'sales_amt': 105.42, 'qty': 2, 'di...   9819    100
# 96  {'id': 5569, 'sales_amt': 119.616, 'qty': 8, '...   9819    100
# 97  {'id': 8821, 'sales_amt': 255.76, 'qty': 4, 'd...   9819    100
# 98  {'id': 2898, 'sales_amt': 241.568, 'qty': 2, '...   9819    100
# 99  {'id': 4, 'sales_amt': 69.3, 'qty': 9, 'discou...   9819    100
#
#                                           next  \
# 0   /mentorskool/v1/sales?offset=501&limit=100
# 1   /mentorskool/v1/sales?offset=501&limit=100
# 2   /mentorskool/v1/sales?offset=501&limit=100
# 3   /mentorskool/v1/sales?offset=501&limit=100
# 4   /mentorskool/v1/sales?offset=501&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=501&limit=100
# 96  /mentorskool/v1/sales?offset=501&limit=100
# 97  /mentorskool/v1/sales?offset=501&limit=100
# 98  /mentorskool/v1/sales?offset=501&limit=100
# 99  /mentorskool/v1/sales?offset=501&limit=100
#
#                                       previous
# 0   /mentorskool/v1/sales?offset=301&limit=100
# 1   /mentorskool/v1/sales?offset=301&limit=100
# 2   /mentorskool/v1/sales?offset=301&limit=100
# 3   /mentorskool/v1/sales?offset=301&limit=100
# 4   /mentorskool/v1/sales?offset=301&limit=100
# ..                                         ...
# 95  /mentorskool/v1/sales?offset=301&limit=100
# 96  /mentorskool/v1/sales?offset=301&limit=100
# 97  /mentorskool/v1/sales?offset=301&limit=100
# 98  /mentorskool/v1/sales?offset=301&limit=100
# 99  /mentorskool/v1/sales?offset=301&limit=100
#
# [100 rows x 5 columns]

# %%
dataframes_to_concat = [df1,df2,df3,df4,df5]
df_final = pd.concat(dataframes_to_concat, ignore_index=True)

# %%
data_df = df_final['data']
data_df = pd.json_normalize(data_df)
data_df
# Out:
#        id  sales_amt  qty  discount  profit_amt  order.order_id  \
# 0    2698   261.9600    2      0.00     41.9136  CA-2014-145317
# 1    6827   731.9400    3      0.00    219.5820  CA-2016-118689
# 2    8154    14.6200    2      0.00      6.8714  CA-2017-140151
# 3    2624   957.5775    5      0.45   -383.0310  CA-2017-127180
# 4    4191    22.3680    2      0.20      2.5164  CA-2017-166709
# ..    ...        ...  ...       ...         ...             ...
# 495   336   105.4200    2      0.00     51.6558  CA-2015-137946
# 496  5569   119.6160    8      0.20     40.3704  CA-2017-157966
# 497  8821   255.7600    4      0.00     81.8432  CA-2017-100622
# 498  2898   241.5680    2      0.20     18.1176  US-2016-164630
# 499     4    69.3000    9      0.00     22.8690  US-2015-108966
#
#     order.ship_mode order.order_status order.order_purchase_date  \
# 0    Standard Class          delivered       2018-07-11 19:46:00
# 1    Standard Class          delivered       2018-05-15 20:24:00
# 2       First Class          delivered       2018-02-28 13:40:00
# 3       First Class          delivered       2018-01-07 21:45:00
# 4    Standard Class          delivered       2018-02-22 00:06:00
# ..              ...                ...                       ...
# 495    Second Class          delivered       2018-03-16 10:34:00
# 496        Same Day          delivered       2018-03-08 15:59:00
# 497  Standard Class          delivered       2018-03-01 21:16:00
# 498  Standard Class          delivered       2018-03-15 18:39:00
# 499  Standard Class          delivered       2018-04-14 00:04:00
#
#     order.order_approved_at  ...  \
# 0          2018-07-13 15:25  ...
# 1          2018-05-15 20:55  ...
# 2          2018-03-01 13:35  ...
# 3          2018-01-07 21:57  ...
# 4          2018-02-22 00:30  ...
# ..                      ...  ...
# 495        2018-03-17 02:45  ...
# 496        2018-03-08 16:30  ...
# 497        2018-03-01 21:30  ...
# 498        2018-03-15 18:50  ...
# 499        2018-04-14 00:29  ...
#
#                                   product.product_name product.colors  \
# 0                    Bush Somerset Collection Bookcase           Pink
# 1    Hon Deluxe Fabric Upholstered Stacking Chairs,...           Pink
# 2    Self-Adhesive Address Labels for Typewriters b...           Pink
# 3        Bretford CR4500 Series Slim Rectangular Table           Blue
# 4                       Eldon Fold 'N Roll Cart System           Blue
# ..                                                 ...            ...
# 495           Strathmore #10 Envelopes, Ultimate White           Pink
# 496                     Clear Mylar Reinforcing Strips           Pink
# 497  Howard Miller 14-1/2" Diameter Chrome Round Wa...           Pink
# 498  DMI Arturo Collection Mission-style Design Woo...           Pink
# 499        Deflect-O Glasstique Clear Desk Accessories           Pink
#
#     product.category product.sub_category product.date_added  \
# 0          Furniture            Bookcases         2016-04-01
# 1          Furniture               Chairs         2016-11-04
# 2    Office Supplies               Labels         2016-08-01
# 3          Furniture               Tables         2016-11-15
# 4    Office Supplies              Storage         2016-08-01
# ..               ...                  ...                ...
# 495  Office Supplies            Envelopes         2015-11-16
# 496  Office Supplies              Binders         2016-02-21
# 497        Furniture          Furnishings         2017-01-27
# 498        Furniture               Chairs         2016-03-15
# 499        Furniture          Furnishings         2016-05-21
#
#     product.manufacturer       product.sizes   product.upc product.weight  \
# 0                   null                   9  640000000000           null
# 1                   null          10,7,6,9,8  664000000000           null
# 2                   null                11.5  887000000000           null
# 3                   null    10.5,10,8.5,8,13  888000000000           null
# 4                   null                null  604000000000           null
# ..                   ...                 ...           ...            ...
# 495                 null                   S  888000000000           null
# 496                 null                null  713000000000           null
# 497         Franco Sarto  8.5,9.5,7.5,9,8,11  720000000000           null
# 498                 null                null  882000000000           null
# 499                 null                null          null           null
#
#     product.product_photos_qty
# 0                            4
# 1                            2
# 2                            3
# 3                            0
# 4                            0
# ..                         ...
# 495                          4
# 496                          3
# 497                          0
# 498                          4
# 499                          0
#
# [500 rows x 35 columns]

# %%
data_df.head(5)
# Out:
#      id  sales_amt  qty  discount  profit_amt  order.order_id order.ship_mode  \
# 0  2698   261.9600    2      0.00     41.9136  CA-2014-145317  Standard Class
# 1  6827   731.9400    3      0.00    219.5820  CA-2016-118689  Standard Class
# 2  8154    14.6200    2      0.00      6.8714  CA-2017-140151     First Class
# 3  2624   957.5775    5      0.45   -383.0310  CA-2017-127180     First Class
# 4  4191    22.3680    2      0.20      2.5164  CA-2017-166709  Standard Class
#
#   order.order_status order.order_purchase_date order.order_approved_at  ...  \
# 0          delivered       2018-07-11 19:46:00        2018-07-13 15:25  ...
# 1          delivered       2018-05-15 20:24:00        2018-05-15 20:55  ...
# 2          delivered       2018-02-28 13:40:00        2018-03-01 13:35  ...
# 3          delivered       2018-01-07 21:45:00        2018-01-07 21:57  ...
# 4          delivered       2018-02-22 00:06:00        2018-02-22 00:30  ...
#
#                                 product.product_name product.colors  \
# 0                  Bush Somerset Collection Bookcase           Pink
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...           Pink
# 2  Self-Adhesive Address Labels for Typewriters b...           Pink
# 3      Bretford CR4500 Series Slim Rectangular Table           Blue
# 4                     Eldon Fold 'N Roll Cart System           Blue
#
#   product.category product.sub_category product.date_added  \
# 0        Furniture            Bookcases         2016-04-01
# 1        Furniture               Chairs         2016-11-04
# 2  Office Supplies               Labels         2016-08-01
# 3        Furniture               Tables         2016-11-15
# 4  Office Supplies              Storage         2016-08-01
#
#   product.manufacturer     product.sizes   product.upc product.weight  \
# 0                 null                 9  640000000000           null
# 1                 null        10,7,6,9,8  664000000000           null
# 2                 null              11.5  887000000000           null
# 3                 null  10.5,10,8.5,8,13  888000000000           null
# 4                 null              null  604000000000           null
#
#   product.product_photos_qty
# 0                          4
# 1                          2
# 2                          3
# 3                          0
# 4                          0
#
# [5 rows x 35 columns]

# %%
data_df.isnull().sum()
# Out:
# id                                     0
# sales_amt                              0
# qty                                    0
# discount                               0
# profit_amt                             0
# order.order_id                         0
# order.ship_mode                        0
# order.order_status                     0
# order.order_purchase_date              0
# order.order_approved_at                0
# order.order_delivered_carrier_date     0
# order.order_delivered_customer_date    0
# order.order_estimated_delivery_date    0
# order.customer.customer_id             0
# order.customer.customer_name           0
# order.customer.segment                 0
# order.customer.contact_number          0
# order.customer.address.zip_code        0
# order.customer.address.region          0
# order.customer.address.country         0
# order.customer.address.city            0
# order.customer.address.state           0
# order.vendor.VendorID                  0
# order.vendor.Vendor Name               0
# product.product_id                     0
# product.product_name                   0
# product.colors                         0
# product.category                       0
# product.sub_category                   0
# product.date_added                     0
# product.manufacturer                   0
# product.sizes                          0
# product.upc                            0
# product.weight                         0
# product.product_photos_qty             0
# dtype: int64

# %%
data_df.duplicated().sum()
# Out:
# 0

# %%
data_df['order.order_purchase_date']=pd.to_datetime(data_df['order.order_purchase_date'])
data_df['day_of_order'] =data_df['order.order_purchase_date'].dt.dayofweek
data_df
# Out:
#        id  sales_amt  qty  discount  profit_amt  order.order_id  \
# 0    2698   261.9600    2      0.00     41.9136  CA-2014-145317
# 1    6827   731.9400    3      0.00    219.5820  CA-2016-118689
# 2    8154    14.6200    2      0.00      6.8714  CA-2017-140151
# 3    2624   957.5775    5      0.45   -383.0310  CA-2017-127180
# 4    4191    22.3680    2      0.20      2.5164  CA-2017-166709
# ..    ...        ...  ...       ...         ...             ...
# 495   336   105.4200    2      0.00     51.6558  CA-2015-137946
# 496  5569   119.6160    8      0.20     40.3704  CA-2017-157966
# 497  8821   255.7600    4      0.00     81.8432  CA-2017-100622
# 498  2898   241.5680    2      0.20     18.1176  US-2016-164630
# 499     4    69.3000    9      0.00     22.8690  US-2015-108966
#
#     order.ship_mode order.order_status order.order_purchase_date  \
# 0    Standard Class          delivered       2018-07-11 19:46:00
# 1    Standard Class          delivered       2018-05-15 20:24:00
# 2       First Class          delivered       2018-02-28 13:40:00
# 3       First Class          delivered       2018-01-07 21:45:00
# 4    Standard Class          delivered       2018-02-22 00:06:00
# ..              ...                ...                       ...
# 495    Second Class          delivered       2018-03-16 10:34:00
# 496        Same Day          delivered       2018-03-08 15:59:00
# 497  Standard Class          delivered       2018-03-01 21:16:00
# 498  Standard Class          delivered       2018-03-15 18:39:00
# 499  Standard Class          delivered       2018-04-14 00:04:00
#
#     order.order_approved_at  ... product.colors product.category  \
# 0          2018-07-13 15:25  ...           Pink        Furniture
# 1          2018-05-15 20:55  ...           Pink        Furniture
# 2          2018-03-01 13:35  ...           Pink  Office Supplies
# 3          2018-01-07 21:57  ...           Blue        Furniture
# 4          2018-02-22 00:30  ...           Blue  Office Supplies
# ..                      ...  ...            ...              ...
# 495        2018-03-17 02:45  ...           Pink  Office Supplies
# 496        2018-03-08 16:30  ...           Pink  Office Supplies
# 497        2018-03-01 21:30  ...           Pink        Furniture
# 498        2018-03-15 18:50  ...           Pink        Furniture
# 499        2018-04-14 00:29  ...           Pink        Furniture
#
#     product.sub_category product.date_added product.manufacturer  \
# 0              Bookcases         2016-04-01                 null
# 1                 Chairs         2016-11-04                 null
# 2                 Labels         2016-08-01                 null
# 3                 Tables         2016-11-15                 null
# 4                Storage         2016-08-01                 null
# ..                   ...                ...                  ...
# 495            Envelopes         2015-11-16                 null
# 496              Binders         2016-02-21                 null
# 497          Furnishings         2017-01-27         Franco Sarto
# 498               Chairs         2016-03-15                 null
# 499          Furnishings         2016-05-21                 null
#
#           product.sizes   product.upc  product.weight  \
# 0                     9  640000000000            null
# 1            10,7,6,9,8  664000000000            null
# 2                  11.5  887000000000            null
# 3      10.5,10,8.5,8,13  888000000000            null
# 4                  null  604000000000            null
# ..                  ...           ...             ...
# 495                   S  888000000000            null
# 496                null  713000000000            null
# 497  8.5,9.5,7.5,9,8,11  720000000000            null
# 498                null  882000000000            null
# 499                null          null            null
#
#     product.product_photos_qty day_of_order
# 0                            4            2
# 1                            2            1
# 2                            3            2
# 3                            0            6
# 4                            0            3
# ..                         ...          ...
# 495                          4            4
# 496                          3            3
# 497                          0            3
# 498                          4            3
# 499                          0            5
#
# [500 rows x 36 columns]

# %%
data_df['order.order_purchase_date']=pd.to_datetime(data_df['order.order_purchase_date'])
data_df['day_of_order'] = data_df['order.order_purchase_date'].dt.dayofweek

# %%
def get_day_label(day_of_order):
  if day_of_order < 5:
    return 'weekday'
  else:
    return 'weekend'

# %%
data_df['day_label'] = data_df['day_of_order'].apply(get_day_label)
data_df
# Out:
#        id  sales_amt  qty  discount  profit_amt  order.order_id  \
# 0    2698   261.9600    2      0.00     41.9136  CA-2014-145317
# 1    6827   731.9400    3      0.00    219.5820  CA-2016-118689
# 2    8154    14.6200    2      0.00      6.8714  CA-2017-140151
# 3    2624   957.5775    5      0.45   -383.0310  CA-2017-127180
# 4    4191    22.3680    2      0.20      2.5164  CA-2017-166709
# ..    ...        ...  ...       ...         ...             ...
# 495   336   105.4200    2      0.00     51.6558  CA-2015-137946
# 496  5569   119.6160    8      0.20     40.3704  CA-2017-157966
# 497  8821   255.7600    4      0.00     81.8432  CA-2017-100622
# 498  2898   241.5680    2      0.20     18.1176  US-2016-164630
# 499     4    69.3000    9      0.00     22.8690  US-2015-108966
#
#     order.ship_mode order.order_status order.order_purchase_date  \
# 0    Standard Class          delivered       2018-07-11 19:46:00
# 1    Standard Class          delivered       2018-05-15 20:24:00
# 2       First Class          delivered       2018-02-28 13:40:00
# 3       First Class          delivered       2018-01-07 21:45:00
# 4    Standard Class          delivered       2018-02-22 00:06:00
# ..              ...                ...                       ...
# 495    Second Class          delivered       2018-03-16 10:34:00
# 496        Same Day          delivered       2018-03-08 15:59:00
# 497  Standard Class          delivered       2018-03-01 21:16:00
# 498  Standard Class          delivered       2018-03-15 18:39:00
# 499  Standard Class          delivered       2018-04-14 00:04:00
#
#     order.order_approved_at  ... product.category product.sub_category  \
# 0          2018-07-13 15:25  ...        Furniture            Bookcases
# 1          2018-05-15 20:55  ...        Furniture               Chairs
# 2          2018-03-01 13:35  ...  Office Supplies               Labels
# 3          2018-01-07 21:57  ...        Furniture               Tables
# 4          2018-02-22 00:30  ...  Office Supplies              Storage
# ..                      ...  ...              ...                  ...
# 495        2018-03-17 02:45  ...  Office Supplies            Envelopes
# 496        2018-03-08 16:30  ...  Office Supplies              Binders
# 497        2018-03-01 21:30  ...        Furniture          Furnishings
# 498        2018-03-15 18:50  ...        Furniture               Chairs
# 499        2018-04-14 00:29  ...        Furniture          Furnishings
#
#     product.date_added product.manufacturer       product.sizes   product.upc  \
# 0           2016-04-01                 null                   9  640000000000
# 1           2016-11-04                 null          10,7,6,9,8  664000000000
# 2           2016-08-01                 null                11.5  887000000000
# 3           2016-11-15                 null    10.5,10,8.5,8,13  888000000000
# 4           2016-08-01                 null                null  604000000000
# ..                 ...                  ...                 ...           ...
# 495         2015-11-16                 null                   S  888000000000
# 496         2016-02-21                 null                null  713000000000
# 497         2017-01-27         Franco Sarto  8.5,9.5,7.5,9,8,11  720000000000
# 498         2016-03-15                 null                null  882000000000
# 499         2016-05-21                 null                null          null
#
#     product.weight  product.product_photos_qty day_of_order day_label
# 0             null                           4            2   weekday
# 1             null                           2            1   weekday
# 2             null                           3            2   weekday
# 3             null                           0            6   weekend
# 4             null                           0            3   weekday
# ..             ...                         ...          ...       ...
# 495           null                           4            4   weekday
# 496           null                           3            3   weekday
# 497           null                           0            3   weekday
# 498           null                           4            3   weekday
# 499           null                           0            5   weekend
#
# [500 rows x 37 columns]

# %%
num_weekend_orders = data_df[data_df['day_label']=='weekend'].shape[0]
num_weekend_orders
# Out:
# 99

# %%
weekday_data = data_df[data_df['day_label'] == 'weekday']
weekend_data = data_df[data_df['day_label'] == 'weekend']

weekday_sales_sum = weekday_data['sales_amt'].sum()
weekend_sales_sum = weekend_data['sales_amt'].sum()

# Compare the sales and find the highest
highest_sales_group = 'weekday' if weekday_sales_sum > weekend_sales_sum else 'weekend'
highest_sales_group
# Out:
# 'weekday'

# %%
sales_by_category = data_df.groupby('product.category')['sales_amt'].sum()

# %%
highest_sales_category = sales_by_category.idxmax()
highest_sales_category
# Out:
# 'Technology'
